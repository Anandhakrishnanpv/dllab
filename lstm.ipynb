# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# %%
text = "A short paragraph is about 100-200 words and focuses on one main topic that is very specific. A short paragraph has supporting details about the main idea and concludes in a way that further promotes the main idea. On the other hand, a long paragraph can be a specific topic or a broad one."

# %%
# asigns a unique integer to each word based on the frequency
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# %%
total_words
# Out:
# 35

# %%
input_sequences = []
for line in text.split('.'):
  token_list = tokenizer.texts_to_sequences([line])[0]
  print(token_list)
  for i in range(1, len(token_list)):
    n_gram_sequence = token_list[:i + 1]
    print(n_gram_sequence)
    input_sequences.append(n_gram_sequence)
# Out:
# [1, 5, 2, 6, 7, 15, 16, 17, 8, 18, 9, 10, 3, 11, 12, 6, 19, 13]
# [1, 5]
# [1, 5, 2]
# [1, 5, 2, 6]
# [1, 5, 2, 6, 7]
# [1, 5, 2, 6, 7, 15]
# [1, 5, 2, 6, 7, 15, 16]
# [1, 5, 2, 6, 7, 15, 16, 17]
# [1, 5, 2, 6, 7, 15, 16, 17, 8]
# [1, 5, 2, 6, 7, 15, 16, 17, 8, 18]
# [1, 5, 2, 6, 7, 15, 16, 17, 8, 18, 9]
# [1, 5, 2, 6, 7, 15, 16, 17, 8, 18, 9, 10]
# [1, 5, 2, 6, 7, 15, 16, 17, 8, 18, 9, 10, 3]
# [1, 5, 2, 6, 7, 15, 16, 17, 8, 18, 9, 10, 3, 11]
# [1, 5, 2, 6, 7, 15, 16, 17, 8, 18, 9, 10, 3, 11, 12]
# [1, 5, 2, 6, 7, 15, 16, 17, 8, 18, 9, 10, 3, 11, 12, 6]
# [1, 5, 2, 6, 7, 15, 16, 17, 8, 18, 9, 10, 3, 11, 12, 6, 19]
# [1, 5, 2, 6, 7, 15, 16, 17, 8, 18, 9, 10, 3, 11, 12, 6, 19, 13]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23, 24, 1, 25, 12, 26, 27, 4, 3, 14]
# [1, 5]
# [1, 5, 2]
# [1, 5, 2, 20]
# [1, 5, 2, 20, 21]
# [1, 5, 2, 20, 21, 22]
# [1, 5, 2, 20, 21, 22, 7]
# [1, 5, 2, 20, 21, 22, 7, 4]
# [1, 5, 2, 20, 21, 22, 7, 4, 3]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23, 24]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23, 24, 1]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23, 24, 1, 25]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23, 24, 1, 25, 12]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23, 24, 1, 25, 12, 26]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23, 24, 1, 25, 12, 26, 27]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23, 24, 1, 25, 12, 26, 27, 4]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23, 24, 1, 25, 12, 26, 27, 4, 3]
# [1, 5, 2, 20, 21, 22, 7, 4, 3, 14, 8, 23, 24, 1, 25, 12, 26, 27, 4, 3, 14]
# [9, 4, 28, 29, 1, 30, 2, 31, 32, 1, 13, 11, 33, 1, 34, 10]
# [9, 4]
# [9, 4, 28]
# [9, 4, 28, 29]
# [9, 4, 28, 29, 1]
# [9, 4, 28, 29, 1, 30]
# [9, 4, 28, 29, 1, 30, 2]
# [9, 4, 28, 29, 1, 30, 2, 31]
# [9, 4, 28, 29, 1, 30, 2, 31, 32]
# [9, 4, 28, 29, 1, 30, 2, 31, 32, 1]
# [9, 4, 28, 29, 1, 30, 2, 31, 32, 1, 13]
# [9, 4, 28, 29, 1, 30, 2, 31, 32, 1, 13, 11]
# [9, 4, 28, 29, 1, 30, 2, 31, 32, 1, 13, 11, 33]
# [9, 4, 28, 29, 1, 30, 2, 31, 32, 1, 13, 11, 33, 1]
# [9, 4, 28, 29, 1, 30, 2, 31, 32, 1, 13, 11, 33, 1, 34]
# [9, 4, 28, 29, 1, 30, 2, 31, 32, 1, 13, 11, 33, 1, 34, 10]
# []

# %%
max_sequence_length = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')
input_sequences
# Out:
# array([[ 0,  0,  0, ...,  0,  1,  5],
#        [ 0,  0,  0, ...,  1,  5,  2],
#        [ 0,  0,  0, ...,  5,  2,  6],
#        ...,
#        [ 0,  0,  0, ..., 11, 33,  1],
#        [ 0,  0,  0, ..., 33,  1, 34],
#        [ 0,  0,  0, ...,  1, 34, 10]], dtype=int32)

# %%
# taking the last column as label and the previous words as feature
x, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
y.shape
# Out:
# (52, 35)

# %%
# defining the model
model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_length - 1))
model.add(LSTM(110))
model.add(Dense(total_words, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x, y, epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.0232 - loss: 3.5564
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1418 - loss: 3.5454
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1651 - loss: 3.5338
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1546 - loss: 3.5221
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1651 - loss: 3.5072
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1627 - loss: 3.4819
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1442 - loss: 3.4463
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1082 - loss: 3.4034
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.0954 - loss: 3.3783
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.0954 - loss: 3.3383
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1186 - loss: 3.3026
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1290 - loss: 3.2499
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1314 - loss: 3.2452
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1210 - loss: 3.1818
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1234 - loss: 3.1517
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1418 - loss: 3.0642
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1522 - loss: 2.9739
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1675 - loss: 2.9464
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1442 - loss: 2.8986
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2163 - loss: 2.8603
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1571 - loss: 2.8066
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2163 - loss: 2.7782
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2652 - loss: 2.7494
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2372 - loss: 2.7019
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2965 - loss: 2.6165
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2292 - loss: 2.5920
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2524 - loss: 2.5347
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2628 - loss: 2.5238
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2941 - loss: 2.4186
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3093 - loss: 2.3836
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2861 - loss: 2.3455
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3325 - loss: 2.2761
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3325 - loss: 2.2502
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3454 - loss: 2.2160
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4175 - loss: 2.1211
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4615 - loss: 2.0555
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4431 - loss: 2.0497
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4976 - loss: 1.9901
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4976 - loss: 1.9475
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4792 - loss: 1.9191
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5312 - loss: 1.8333
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5361 - loss: 1.8137
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5593 - loss: 1.7639
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5617 - loss: 1.7453
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6058 - loss: 1.6597
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5280 - loss: 1.6521
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6522 - loss: 1.5967
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6082 - loss: 1.5571
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6546 - loss: 1.5121
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6082 - loss: 1.4867
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6290 - loss: 1.4586
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7035 - loss: 1.4271
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7011 - loss: 1.3790
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7500 - loss: 1.3466
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7292 - loss: 1.3553
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7035 - loss: 1.3042
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7756 - loss: 1.2686
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7756 - loss: 1.2202
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8117 - loss: 1.2050
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8662 - loss: 1.1319
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8606 - loss: 1.1413
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8349 - loss: 1.1175
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9046 - loss: 1.0662
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9151 - loss: 1.0444
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8710 - loss: 1.0306
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9046 - loss: 0.9839
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9255 - loss: 0.9553
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8582 - loss: 0.9683
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8838 - loss: 0.9472
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9383 - loss: 0.8866
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9175 - loss: 0.8932
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9175 - loss: 0.8628
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9279 - loss: 0.8382
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9279 - loss: 0.8011
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9279 - loss: 0.7955
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9279 - loss: 0.7720
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9046 - loss: 0.7886
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9279 - loss: 0.7139
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9071 - loss: 0.7460
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9279 - loss: 0.7216
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9407 - loss: 0.6810
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9407 - loss: 0.6772
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9511 - loss: 0.6418
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9383 - loss: 0.6201
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9407 - loss: 0.6242
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9175 - loss: 0.6465
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9303 - loss: 0.6308
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9639 - loss: 0.6908
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9407 - loss: 0.6410
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9768 - loss: 0.5879
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.6475
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9639 - loss: 0.6289
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9872 - loss: 0.5716
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9768 - loss: 0.5886
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9872 - loss: 0.5713
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9768 - loss: 0.5505
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9768 - loss: 0.5402
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9768 - loss: 0.5102
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9872 - loss: 0.4820
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9768 - loss: 0.5045

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 20, 100)             │           3,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 110)                 │          92,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 35)                  │           3,885 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 300,677 (1.15 MB)
#  Trainable params: 100,225 (391.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 200,452 (783.02 KB)

# %%
def predict_next_word(model, tokenizer, input_text):
  input_seq = tokenizer.texts_to_sequences([input_text])[0]
  input_seq = pad_sequences([input_seq], maxlen=max_sequence_length - 1, padding='pre')
  predicted = model.predict(input_seq,verbose=0)
  return tokenizer.index_word[np.argmax(predicted)]

# %%
input_text= "LSTM is a"
next_word = predict_next_word(model, tokenizer, input_text)
print(f"Next word prediction:", next_word)
# Out:
# Next word prediction: short
